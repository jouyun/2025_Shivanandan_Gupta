# %%
import napari
import scipy as sp
import numpy as np
import tifffile
import scipy.ndimage as ndi
from skimage.feature import peak_local_max
import os
import glob
import cv2
import skimage as ski
import dask
import plotly.express as px
import pandas as pd
import plotly.graph_objs as go

# %% [markdown]
# # Setup Notebook

# %%
viewer = napari.Viewer()

# %%
# Choose the channel to find CenpA peaks in
peak_channel = 1

# %%
scale = [0.10, 0.031, 0.031]

# %% [markdown]
# # Utility Functions

# %%
def backsub(inp, radius=20):
    filterSize =(radius, radius)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,
                                    filterSize)
    blurred = cv2.GaussianBlur(inp, (5, 5), 0)
    tophat_img = cv2.morphologyEx(blurred,
                                cv2.MORPH_TOPHAT,
                                kernel)
    rtn = inp.astype(np.single) - (blurred-tophat_img)
    rtn = np.clip(rtn, 0, np.inf)
    return rtn
def backsub_3d(inp, radius=20):
    shape = inp.shape
    reshaped = inp.reshape(-1, shape[-2], shape[-1])
    process = [dask.delayed(backsub)(i, radius) for i in reshaped]
    rslt = np.array(dask.compute(*process))
    rslt = rslt.reshape(shape)
    return rslt

# %%
def filter_label_size(labels, min_size=10, max_size=100):
    from skimage import measure
    label_sizes = np.bincount(labels.ravel())
    too_small = label_sizes < min_size
    too_large = label_sizes > max_size
    labels[np.isin(labels, np.where(too_small | too_large))] = 0
    labels = ski.segmentation.relabel_sequential(labels)[0]
    return labels

# %%
def find_peaks(img, threshold=0.1, display=False):
    #LoG = -ndi.gaussian_laplace(img/1000, sigma=[2,4,4])
    #LoG = -ndi.gaussian_laplace(img/1000, sigma=[1,2,2])
    
    img = ski.transform.rescale(img, [0.5,1,1], order=1, preserve_range=True)
    LoG = -ndi.gaussian_laplace(img/1000, sigma=[2,2,2])
    max_peaks = peak_local_max(LoG, min_distance=1, threshold_rel=threshold)
    if display:
        viewer.add_image(LoG, blending='additive', colormap='magenta', scale=scale)
        viewer.add_points(max_peaks, n_dimensional=True, size=6, scale=scale, name='AllPeaks')
    return max_peaks

def pair_finder(peaks, max_dist=6, scale=[0.12, 0.04, 0.04]):
    scaled_peaks = peaks.copy().astype(float)
    scaled_peaks[:,0] = scaled_peaks[:,0] * scale[0]
    scaled_peaks[:,1] = scaled_peaks[:,1] * scale[1]
    scaled_peaks[:,2] = scaled_peaks[:,2] * scale[2]
    
    d_matrix = sp.spatial.distance.squareform(sp.spatial.distance.pdist(scaled_peaks))
    d_matrix[d_matrix==0] = 10000
    
    min_pos = np.argmin(d_matrix, axis=0)
    distances = np.min(d_matrix, axis=0)
    sorte = np.argsort(distances)
    
    return_distances = []
    lst = []
    for a in np.arange(0,len(sorte)):
        if distances[sorte[a]]<max_dist:
            if any([all (peaks[sorte[a]]==b) for b in lst]) | any([all(peaks[min_pos][sorte[a]]==b) for b in lst]):
                lst
            elif np.abs(peaks[sorte[a]][0]-peaks[min_pos][sorte[a]][0])>6:
                lst
            else:
                lst.append(peaks[sorte[a]])
                lst.append(peaks[min_pos][sorte[a]])
                return_distances.append(distances[sorte[a]])
    return lst, return_distances

def find_peaks_in_file(fname, display=False, threshold=0.16, viewer=None):
    img = tifffile.imread(fname)
    peaks = find_peaks(img[:,peak_channel,:,:], threshold=threshold, display=display)
    filtered_peaks, distances = pair_finder(peaks, max_dist=1.2, scale=scale)
    
    if display:
        viewer.add_image(img, channel_axis=1, scale=scale)
        viewer.add_points(filtered_peaks[::2], n_dimensional=True, size=6, scale=scale, name='FilteredPeaks', face_color='magenta')
        viewer.add_points(filtered_peaks[1::2], n_dimensional=True, size=6, scale=scale, name='FilteredPeaks', face_color='yellow')
    return filtered_peaks, distances

# %%
def get_intensity_df(int_img, labels):
    df = pd.DataFrame(ski.measure.regionprops_table(labels, intensity_image=int_img, properties=['label', 'mean_intensity', 'area']))
    df['total_intensity'] = df['mean_intensity'] * df['area']
    return df.drop(columns=['area'])

def get_props_df(labels):
    df = pd.DataFrame(ski.measure.regionprops_table(labels, properties=['label', 'centroid', 'area']))
    return df

def get_all_props(int_img, labels):
    props_df = get_props_df(labels)
    c0_df = get_intensity_df(int_img[0], labels)
    c1_df = get_intensity_df(int_img[1], labels)
    c2_df = get_intensity_df(int_img[2], labels)
    c3_df = get_intensity_df(int_img[3], labels)
    all_df = props_df.merge(c0_df, on='label', suffixes=('', '_c0'))
    all_df = all_df.merge(c1_df, on='label', suffixes=('', '_c1'))
    all_df = all_df.merge(c2_df, on='label', suffixes=('', '_c2'))
    all_df = all_df.merge(c3_df, on='label', suffixes=('', '_c3'))
    return all_df

# %%
def get_mask(peak, img_shape, radius=6):
    blank_img = np.zeros(img_shape)
    cv2.line(blank_img, tuple(peak[0].astype(int)[::-1]), tuple(peak[1].astype(int)[::-1]), color=255, thickness=2)
    edt = ndi.distance_transform_edt(blank_img==0)
    binary = edt < radius
    return binary

def process_file(fname, viewer=None, display=False, max_distance=20):

    # Get peak pairs and distances
    peaks, distances = find_peaks_in_file(fname, display=display, viewer=viewer, threshold=0.16)
    pks_grouped = np.reshape(peaks, (-1, 2, 3))
    centers = np.mean(pks_grouped, axis=1)[:,1:3]
    if len(centers) < 4:
        print(f"Not enough peaks found in {fname}. Skipping file.")
        return pd.DataFrame()

    img = ski.io.imread(fname)
    img = np.moveaxis(img, -1, 0)
    img = backsub_3d(img, radius=20)

    # Get the brightest 2 objects in the FISH channel (0)
    fimg = img[0,:,:,:]
    pimg = fimg.sum(axis=0)[:,:]
    otsu = 0.25 * ski.filters.threshold_otsu(pimg)
    binary = pimg > otsu
    labels = ski.measure.label(binary)
    if np.max(labels) < 2:
        print(f"Not enough FISH labels found in {fname}. Skipping file.")
        return pd.DataFrame()
    df = pd.DataFrame(ski.measure.regionprops_table(labels, intensity_image=pimg, properties=['label', 'area', 'centroid', 'mean_intensity']))
    labels = filter_label_size(labels, min_size=20, max_size=500)
    df = pd.DataFrame(ski.measure.regionprops_table(labels, intensity_image=pimg, properties=['label', 'area', 'centroid', 'mean_intensity']))
    df['total_intensity'] = df['mean_intensity'] * df['area']
    df = df.sort_values(by='total_intensity', ascending=False).rename(columns={'centroid-0': 'y', 'centroid-1': 'x'})
    if display:
        viewer.add_labels(labels, name='FISH Labels', scale=scale[1:])
    if len(df) < 2:
        print(f"Not enough FISH peaks found in {fname}. Skipping file.")
        return pd.DataFrame()

    # Get the bright and dim peaks from the FISH channel, calculate distances to all pairs' centers
    bright = df.iloc[0][['y','x']].values
    dim = df.iloc[1][['y','x']].values
    bright_distances = np.linalg.norm(centers - bright, axis=1)
    dim_distances = np.linalg.norm(centers - dim, axis=1)

    # Find the closest peak to the bright and dim FISH spots and their distances
    bright_peak = pks_grouped[np.argmin(bright_distances)][:,1:3]
    dim_peak = pks_grouped[np.argmin(dim_distances)][:,1:3]
    bright_peak_distance = bright_distances[np.argmin(bright_distances)]
    dim_peak_distance = dim_distances[np.argmin(dim_distances)]
    if bright_peak_distance > max_distance or dim_peak_distance > max_distance:
        print(f"Bright peak distance {bright_peak_distance} or dim peak distance {dim_peak_distance} exceeds max distance {max_distance}.")
        return pd.DataFrame()

    # Draw line connecting the 2 bright peaks and make a mask, and another for the dim peaks
    bright_mask = get_mask([bright_peak[0], bright_peak[1]], pimg.shape)
    dim_mask = get_mask([dim_peak[0], dim_peak[1]], pimg.shape)
    both_labels = bright_mask + dim_mask * 2

    # Get the intensity information for all channels
    proj_img = img.sum(axis=1)
    prop_df = get_all_props(proj_img, both_labels)

    if display:
        viewer.add_image(proj_img, scale=scale[1:], channel_axis=0)
        viewer.add_labels(both_labels, name='Areas', scale=scale[1:])
        viewer.layers[-1].contour = 2
    
    prop_df['FISH_area'] = df['area'].iloc[0:2].values
    prop_df['FISH_total_intensity'] = df['total_intensity'].iloc[0:2].values
    prop_df['FISH_mean_intensity'] = df['mean_intensity'].iloc[0:2].values
    prop_df['distance'] = np.array([bright_peak_distance, dim_peak_distance])
    prop_df['slices'] = img.shape[1]
    
    return prop_df

# %% [markdown]
# # Process Data

# %%
fnames = glob.glob('*/crop_rep*/*.tif')
fname = fnames[15]
fnames
# Out:
# ['Cen11_CENPB_CENPA\\crop_rep0\\Image005-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image005-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image006-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image008-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image008-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image009-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image010-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image010-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image011-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image011-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image012-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image012-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image012-3-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image013-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image013-2.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image014-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image014-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image015-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image016-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image016-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image017-1-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image017-2-1.tif',
#  'Cen11_CENPB_CENPA\\crop_rep0\\Image017-3-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1001-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1001-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1003-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1003-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1004-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1006-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1006-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1007-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1007-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1008-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep1\\Cen11_image1012-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1003-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1004-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1004-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1007-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1010-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1011-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1012-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1013-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1014-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1016-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1019-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep2\\Cen11_image1020-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image001-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image001-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image002-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image002-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image002-3.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image002-4.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image003-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image004-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image005-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image006-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image007-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image008-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image009-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image009-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image011-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image011-2.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image012-1.tif',
#  'Cen11_KNL1_CENPA\\crop_rep3\\rep3_image013-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image001-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image001-2.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image005-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image006-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image006-2.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image007-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image009-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image010-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image010-2.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image011-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep1\\rep1_image012-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image001-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image003-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image004-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image004-2.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image005-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image007-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image009-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image010-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image013-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep2\\rep2_image014-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep3\\rep3_image001-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep3\\rep3_image002-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep3\\rep3_image004-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep3\\rep3_image004-2.tif',
#  'Cen11_NDC80_CENPA\\crop_rep3\\rep3_image005-1.tif',
#  'Cen11_NDC80_CENPA\\crop_rep3\\rep3_
#    mean_intensity_c1  total_intensity_c1  mean_intensity_c2  \
# 0         359.631287       199954.995361       42512.093750
# 1         302.195923       177389.006714       31383.332031
#
#    total_intensity_c2  mean_intensity_c3  total_intensity_c3  FISH_area  \
# 0        2.363672e+07        4707.208496        2.617208e+06      188.0
# 1        1.842202e+07        3916.161865        2.298787e+06      102.0
#
#    FISH_total_intensity  FISH_mean_intensity   distance  slices
# 0          4.851390e+06         25805.265625  15.401784      10
# 1          1.628793e+06         15968.558594  16.338032      10

# %%
df = pd.DataFrame()
for fname in fnames:
    print(fname)
    prop_df = process_file(fname, viewer=viewer, display=False, max_distance=20)
    prop_df['filename'] = fname
    df = pd.concat([df, prop_df])
# Out:
# Cen11_CENPB_CENPA\crop_rep0\Image005-1-1.tif
# Bright peak distance 30.536214825662608 or dim peak distance 22.480871370881584 exceeds max distance 20.
# Cen11_CENPB_CENPA\crop_rep0\Image005-2-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image006-1-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image008-1-1.tif
# Bright peak distance 20.133730596947817 or dim peak distance 12.006934745989915 exceeds max distance 20.
# Cen11_CENPB_CENPA\crop_rep0\Image008-2-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image009-1-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image010-1-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image010-2-1.tif
# Bright peak distance 23.878146824451708 or dim peak distance 10.946911894969078 exceeds max distance 20.
# Cen11_CENPB_CENPA\crop_rep0\Image011-1-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image011-2-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image012-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image012-2-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image012-3-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image013-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image013-2.tif
# Bright peak distance 1.1252747362251956 or dim peak distance 20.1294976564314 exceeds max distance 20.
# Cen11_CENPB_CENPA\crop_rep0\Image014-1-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image014-2-1.tif
# Bright peak distance 86.42436923480054 or dim peak distance 1.344069069946085 exceeds max distance 20.
# Cen11_CENPB_CENPA\crop_rep0\Image015-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image016-1-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image016-2-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image017-1-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image017-2-1.tif
# Cen11_CENPB_CENPA\crop_rep0\Image017-3-1.tif
# Bright peak distance 22.414306222200846 or dim peak distance 29.839210314990275 exceeds max distance 20.
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1001-1.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1001-2.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1003-1.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1003-2.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1004-1.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1006-1.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1006-2.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1007-1.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1007-2.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1008-1.tif
# Cen11_KNL1_CENPA\crop_rep1\Cen11_image1012-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1003-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1004-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1004-2.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1007-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1010-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1011-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1012-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1013-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1014-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1016-1.tif
# Bright peak distance 1.8637740342508125 or dim peak distance 26.671942766293398 exceeds max distance 20.
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1019-1.tif
# Cen11_KNL1_CENPA\crop_rep2\Cen11_image1020-1.tif
# Bright peak distance 0.9037888713831244 or dim peak distance 23.343473040171176 exceeds max distance 20.
# Cen11_KNL1_CENPA\crop_rep3\rep3_image001-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image001-2.tif
# Bright peak distance 35.24976174602208 or dim peak distance 2.487901496587008 exceeds max distance 20.
# Cen11_KNL1_CENPA\crop_rep3\rep3_image002-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image002-2.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image002-3.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image002-4.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image003-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image004-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image005-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image006-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image007-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image008-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image009-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image009-2.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image011-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image011-2.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image012-1.tif
# Cen11_KNL1_CENPA\crop_rep3\rep3_image013-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image001-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image001-2.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image005-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image006-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image006-2.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image007-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image009-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image010-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image010-2.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image011-1.tif
# Cen11_NDC80_CENPA\crop_rep1\rep1_image012-1.tif
# Cen11_NDC80_CENPA\crop_rep2\rep2_
tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image004-1.tif
# Bright peak distance 21.467186589498137 or dim peak distance 0.6173880054700867 exceeds max distance 20.
# Cen7_KNL1_CENPA\crop_rep3\rep3_image006-1.tif
# Bright peak distance 42.94272424899136 or dim peak distance 0.9902207844483111 exceeds max distance 20.
# Cen7_KNL1_CENPA\crop_rep3\rep3_image007-1.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image007-2.tif
# Bright peak distance 23.07892459697621 or dim peak distance 0.8748039328194036 exceeds max distance 20.
# Cen7_KNL1_CENPA\crop_rep3\rep3_image008-1.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image009-1.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image009-2.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image009-3.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image010-1.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image010-2.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image012-1.tif
# Cen7_KNL1_CENPA\crop_rep3\rep3_image013-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image001-1_f.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image001-2.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image003-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image004-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image005-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image006-1_f.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image006-2.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image007-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image007-2.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image009-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image010-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image011-1.tif
# Bright peak distance 22.341896871105106 or dim peak distance 1.1006784993057688 exceeds max distance 20.
# Cen7_NDC80_CENPA\crop_rep1\rep1_image012-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image012-2.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image013-1.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image014-1.tif
# Not enough peaks found in Cen7_NDC80_CENPA\crop_rep1\rep1_image014-1.tif. Skipping file.
# Cen7_NDC80_CENPA\crop_rep1\rep1_image014-2_f.tif
# Cen7_NDC80_CENPA\crop_rep1\rep1_image015-1.tif
# Bright peak distance 23.00451966107098 or dim peak distance 2.0813443146962722 exceeds max distance 20.
# Cen7_NDC80_CENPA\crop_rep2\rep2_image002-1_f.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image002-2_f.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image002-3_f.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image003-1.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image005-1.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image006-1.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image006-2.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image008-1.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image010-1.tif
# Cen7_NDC80_CENPA\crop_rep2\rep2_image014-1.tif
# Bright peak distance 4.354846655307446 or dim peak distance 32.986411338455255 exceeds max distance 20.
# Cen7_NDC80_CENPA\crop_rep2\rep2_image015-1.tif

# %% [markdown]
# # Analyze Data

# %%
df['State'] = 'Bright'
df.iloc[1::2, df.columns.get_loc('State')] = 'Dim'

# %%
df['folder'] = df['filename'].str.split('\\').str[0]
df['rep'] = df['filename'].str.split('\\').str[1]
df.groupby(['folder', 'rep']).agg({'label': 'count','slices':np.mean}).reset_index()
# Out:
# C:\Users\smc\AppData\Local\Temp\ipykernel_21064\1728941320.py:3: FutureWarning:
#
# The provided callable <function mean at 0x000002B5A67244A0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#                 folder        rep  label     slices
# 0    Cen11_CENPB_CENPA  crop_rep0     34  21.647059
# 1     Cen11_KNL1_CENPA  crop_rep1     22  20.272727
# 2     Cen11_KNL1_CENPA  crop_rep2     22  22.090909
# 3     Cen11_KNL1_CENPA  crop_rep3     34  24.764706
# 4    Cen11_NDC80_CENPA  crop_rep1     22  26.090909
# 5    Cen11_NDC80_CENPA  crop_rep2     18  22.000000
# 6    Cen11_NDC80_CENPA  crop_rep3     24  32.000000
# 7   Cen7_AuroraB_CENPA  crop_rep1     20  35.400000
# 8   Cen7_AuroraB_CENPA  crop_rep2     28  29.785714
# 9     Cen7_CENPB_CENPA  crop_rep0     16  11.250000
# 10    Cen7_CENPB_CENPA  crop_rep1     38  19.578947
# 11    Cen7_CENPB_CENPA  crop_rep2     18  21.111111
# 12    Cen7_CENPB_CENPA  crop_rep3     20  14.800000
# 13   Cen7_INCENP_CENPA  crop_rep2     20  31.400000
# 14   Cen7_INCENP_CENPA  crop_rep5     26  41.307692
# 15     Cen7_KNL1_CENPA  crop_rep1     14  22.142857
# 16     Cen7_KNL1_CENPA  crop_rep2     42  24.428571
# 17     Cen7_KNL1_CENPA  crop_rep3     42  17.428571
# 18    Cen7_NDC80_CENPA  crop_rep1     30  26.800000
# 19    Cen7_NDC80_CENPA  crop_rep2     20  24.300000

# %%
bright_df = df[df['State'] == 'Bright']
dim_df = df[df['State'] == 'Dim']

combined_df = bright_df.merge(dim_df, on=['filename', 'folder', ], suffixes=('_bright', '_dim'))
combined_df['FISH_ratio']= combined_df['FISH_total_intensity_bright'] / combined_df['FISH_total_intensity_dim']
combined_df['c0_ratio'] = combined_df['total_intensity_bright'] / combined_df['total_intensity_dim']
combined_df['c1_ratio'] = combined_df['total_intensity_c1_bright'] / combined_df['total_intensity_c1_dim']
combined_df['c2_ratio'] = combined_df['total_intensity_c2_bright'] / combined_df['total_intensity_c2_dim']
combined_df['c3_ratio'] = combined_df['total_intensity_c3_bright'] / combined_df['total_intensity_c3_dim']

combined_df['FISH_ratio_i'] = 1 / combined_df['FISH_ratio']
combined_df['c0_ratio_i'] = 1 / combined_df['c0_ratio']
combined_df['c1_ratio_i'] = 1 / combined_df['c1_ratio']
combined_df['c2_ratio_i'] = 1 / combined_df['c2_ratio']
combined_df['c3_ratio_i'] = 1 / combined_df['c3_ratio']
combined_df
# Out:
#                                            filename  label_bright  \
# 0      Cen11_CENPB_CENPA\crop_rep0\Image005-2-1.tif           1.0
# 1      Cen11_CENPB_CENPA\crop_rep0\Image006-1-1.tif           1.0
# 2      Cen11_CENPB_CENPA\crop_rep0\Image008-2-1.tif           1.0
# 3      Cen11_CENPB_CENPA\crop_rep0\Image009-1-1.tif           1.0
# 4      Cen11_CENPB_CENPA\crop_rep0\Image010-1-1.tif           1.0
# ..                                              ...           ...
# 250  Cen7_NDC80_CENPA\crop_rep2\rep2_image006-1.tif           1.0
# 251  Cen7_NDC80_CENPA\crop_rep2\rep2_image006-2.tif           1.0
# 252  Cen7_NDC80_CENPA\crop_rep2\rep2_image008-1.tif           1.0
# 253  Cen7_NDC80_CENPA\crop_rep2\rep2_image010-1.tif           1.0
# 254  Cen7_NDC80_CENPA\crop_rep2\rep2_image015-1.tif           1.0
#
#      centroid-0_bright  centroid-1_bright  area_bright  mean_intensity_bright  \
# 0                 43.0               25.5        202.0            6678.208008
# 1                 59.0               63.0        259.0            4550.405273
# 2                 54.0               40.5        262.0            3657.500000
# 3                227.5               47.5        280.0            3336.357178
# 4                 52.0               40.5        466.0            1656.057983
# ..                 ...                ...          ...                    ...
# 250               24.5               23.0        310.0            4312.044922
# 251               65.5               42.0        280.0            2326.782227
# 252              329.5               79.5        238.0            4083.836182
# 253              261.5              150.0        258.0            5979.356445
# 254               43.0              136.5        266.0            2457.676758
#
#      total_intensity_bright  mean_intensity_c1_bright  \
# 0              1.348998e+06               2914.054443
# 1              1.178555e+06               3300.525146
# 2              9.582650e+05               4565.309082
# 3              9.341800e+05               3154.071533
# 4              7.717230e+05               3351.866943
# ..                      ...                       ...
# 250            1.336734e+06                443.383881
# 251            6.514990e+05                469.857147
# 252            9.719530e+05                321.663879
# 253            1.542674e+06                413.604645
# 254            6.537420e+05                829.060181
#
#      total_intensity_c1_bright  mean_intensity_c2_bright  ...  FISH_ratio  \
# 0                 5.886390e+05              10070.732422  ...    5.139688
# 1                 8.548360e+05               8664.069336  ...    1.464497
# 2                 1.196111e+06              17636.916016  ...    1.424610
# 3                 8.831400e+05              10976.286133  ...    1.724991
# 4                 1.561970e+06              13776.659180  ...    1.087691
# ..                         ...                       ...  ...         ...
# 250               1.374490e+05              10625.077148  ...    1.952146
# 251               1.315600e+05              18281.410156  ...    2.025689
# 252               7.655600e+04              16343.428711  ...    2.234588
# 253               1.067100e+05               8592.771484  ...    1.317193
# 254               2.205300e+05              14912.522461  ...    2.379647
#
#      c0_ratio  c1_ratio  c2_ratio  c3_ratio  FISH_ratio_i  c0_ratio_i  \
# 0    3.599882  0.652633  0.873813  0.345908      0.194564    0.277787
# 1    1.403802  0.923508  0.838094  1.095782      0.682828    0.712351
# 2    1.342634  1.002469  0.954634  1.811206      0.701947    0.744804
# 3    1.577500  1.459948  1.282037  1.264805      0.579713    0.633914
# 4    1.082527  1.149994  1.543461  1.563911      0.919379    0.923764
# ..        ...       ...       ...       ...           ...         ...
# 250  1.775041  0.621098  0.926863  1.042264      0.512257    0.563367
# 251  0.851452  0.919537  1.179384  1.568109      0.493659    1.174464
# 252  1.772059  1.073040  0.944609  0.745072      0.447510    0.564315
# 253  1.180988  1.252906  0.850141  1.341735      0.759190    0.846749
# 254  1.584153  1.097197  1.013683  1.472736      0.420230    0.631252
#
#      c1_ratio_i c2_ratio_i c3_ratio_i
# 0      1.532255   1.144410   2.890938
# 1      1.082828   1.193184   0.912590
# 2      0.997537   1.047522   0.552118
# 3      0.684956   0.780009   0.790636
# 4      0.869570   0.647894   0.639423
# ..          ...        ...        ...
# 250    1.610052   1.078908   0.959450
# 251    1.087504   0.847900   0.637711
# 252    0.931932   1.058639   1.342151
# 253    0.798144   1.176275   0.745303
# 254    0.911413   0.986501   0.679008
#
# [255 rows x 50 columns]

# %%
# Make interactive plot for examining FISH signal ratios

f=go.FigureWidget(
    #px.box(df, x='folder', color='State', y='total_intensity_c3', points='all', hover_data=['filename'])
    px.box(combined_df, x='folder', y='FISH_ratio_i', points='all', hover_data=['filename'], range_y=[0,2])
    )

def click_fn(trace, points, state):
    
    if (len(points.point_inds)>0):
        idx = f.data[points.trace_index]['customdata'][points.point_inds[-1]][0]
        print(idx)
        viewer.layers.clear()
        process_file(idx, viewer=viewer, display=True)

for a in f.data:
    a.on_click(click_fn)
f.write_html('FISH_signal_ratio.html')
f
# Out:
# FigureWidget({
#     'data': [{'alignmentgroup': 'True',
#               'boxpoints': 'all',
#               'customdata': array([['Cen11_CENPB_CENPA\\crop_rep0\\Image005-2-1.tif'],
#                                    ['Cen11_CENPB_CENPA\\crop_rep0\\Image006-1-1.tif'],
#                                    ['Cen11_CENPB_CENPA\\crop_rep0\\Image008-2-1.tif'],
#                                    ...,
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image008-1.tif'],
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image010-1.tif'],
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image015-1.tif']], dtype=object),
#               'hovertemplate': 'folder=%{x}<br>FISH_ratio_i=%{y}<br>filename=%{customdata[0]}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa'},
#               'name': '',
#               'notched': False,
#               'offsetgroup': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'box',
#               'uid': '95608721-5c1a-41bf-aa52-d3a1f6f615ca',
#               'x': array(['Cen11_CENPB_CENPA', 'Cen11_CENPB_CENPA', 'Cen11_CENPB_CENPA', ...,
#                           'Cen7_NDC80_CENPA', 'Cen7_NDC80_CENPA', 'Cen7_NDC80_CENPA'],
#                          dtype=object),
#               'x0': ' ',
#               'xaxis': 'x',
#               'y': {'bdata': ('8OinCnznyD+Bvph8utnlP/uR5LVYdu' ... 'GkIACk3D+60ZKASUvoP99ThdYN5do/'),
#                     'dtype': 'f8'},
#               'y0': ' ',
#               'yaxis': 'y'}],
#     'layout': {'boxmode': 'group',
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'folder'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'range': [0, 2], 'title': {'text': 'FISH_ratio_i'}}}
# })

# %%
# Make interactive plot for examining CenpA signal ratios

f=go.FigureWidget(
    #px.box(df, x='folder', color='State', y='total_intensity_c3', points='all', hover_data=['filename'])
    px.box(combined_df, x='folder', y='c1_ratio_i', points='all', hover_data=['filename'], range_y=[0,2])
    )

def click_fn(trace, points, state):
    
    if (len(points.point_inds)>0):
        idx = f.data[points.trace_index]['customdata'][points.point_inds[-1]][0]
        print(idx)
        viewer.layers.clear()
        process_file(idx, viewer=viewer, display=True)

for a in f.data:
    a.on_click(click_fn)
f.write_html('cenpA_signal_ratio.html')
f
# Out:
# FigureWidget({
#     'data': [{'alignmentgroup': 'True',
#               'boxpoints': 'all',
#               'customdata': array([['Cen11_CENPB_CENPA\\crop_rep0\\Image005-2-1.tif'],
#                                    ['Cen11_CENPB_CENPA\\crop_rep0\\Image006-1-1.tif'],
#                                    ['Cen11_CENPB_CENPA\\crop_rep0\\Image008-2-1.tif'],
#                                    ...,
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image008-1.tif'],
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image010-1.tif'],
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image015-1.tif']], dtype=object),
#               'hovertemplate': 'folder=%{x}<br>c1_ratio_i=%{y}<br>filename=%{customdata[0]}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa'},
#               'name': '',
#               'notched': False,
#               'offsetgroup': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'box',
#               'uid': '578c082a-d23b-4d0c-83b5-aa0df7ff3c57',
#               'x': array(['Cen11_CENPB_CENPA', 'Cen11_CENPB_CENPA', 'Cen11_CENPB_CENPA', ...,
#                           'Cen7_NDC80_CENPA', 'Cen7_NDC80_CENPA', 'Cen7_NDC80_CENPA'],
#                          dtype=object),
#               'x0': ' ',
#               'xaxis': 'x',
#               'y': {'bdata': ('mTYWsh2E+D9j5aP4QlPxP2Ue78LS6+' ... 'pYVWPS7T8vugBOZorpP4oH2mNMKu0/'),
#                     'dtype': 'f8'},
#               'y0': ' ',
#               'yaxis': 'y'}],
#     'layout': {'boxmode': 'group',
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'folder'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'range': [0, 2], 'title': {'text': 'c1_ratio_i'}}}
# })

# %%
# Make interactive plot for examining kinteochore protein signal ratios
f=go.FigureWidget(
    px.box(combined_df, x='folder', y='c2_ratio_i', points='all', hover_data=['filename'], range_y=[0,2], height=800)
    )

def click_fn(trace, points, state):
    
    if (len(points.point_inds)>0):
        idx = f.data[points.trace_index]['customdata'][points.point_inds[-1]][0]
        print(idx)
        process_file(idx, viewer=viewer, display=True)
        for layer in viewer.layers:
            layer.visible = False
        viewer.layers[-1].visible = True
        viewer.layers[-4].visible = True
        viewer.layers[-5].visible = True
        viewer.layers[-6].visible = True
        viewer.layers[-1].name = idx

for a in f.data:
    a.on_click(click_fn)
f.write_html('core_protein_signal_ratio.html')
f
# Out:
# FigureWidget({
#     'data': [{'alignmentgroup': 'True',
#               'boxpoints': 'all',
#               'customdata': array([['Cen11_CENPB_CENPA\\crop_rep0\\Image005-2-1.tif'],
#                                    ['Cen11_CENPB_CENPA\\crop_rep0\\Image006-1-1.tif'],
#                                    ['Cen11_CENPB_CENPA\\crop_rep0\\Image008-2-1.tif'],
#                                    ...,
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image008-1.tif'],
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image010-1.tif'],
#                                    ['Cen7_NDC80_CENPA\\crop_rep2\\rep2_image015-1.tif']], dtype=object),
#               'hovertemplate': 'folder=%{x}<br>c2_ratio_i=%{y}<br>filename=%{customdata[0]}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa'},
#               'name': '',
#               'notched': False,
#               'offsetgroup': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'box',
#               'uid': 'b97ab983-637c-4a98-b6e6-916d848f3efd',
#               'x': array(['Cen11_CENPB_CENPA', 'Cen11_CENPB_CENPA', 'Cen11_CENPB_CENPA', ...,
#                           'Cen7_NDC80_CENPA', 'Cen7_NDC80_CENPA', 'Cen7_NDC80_CENPA'],
#                          dtype=object),
#               'x0': ' ',
#               'xaxis': 'x',
#               'y': {'bdata': ('Y/fWq4BP8j+aI+07SBfzPwdqtGOmwv' ... 'Lp8y/w8D/Mo6ueBdLyP2mPYwJrke8/'),
#                     'dtype': 'f8'},
#               'y0': ' ',
#               'yaxis': 'y'}],
#     'layout': {'boxmode': 'group',
#                'height': 800,
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'folder'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'range': [0, 2], 'title': {'text': 'c2_ratio_i'}}}
# })

# %%
df.groupby(['folder']).agg({'label':'size', 'filename':lambda x: len(np.unique(x))}).reset_index()
# Out:
#                folder  label  filename
# 0   Cen11_CENPB_CENPA     34        17
# 1    Cen11_KNL1_CENPA     78        39
# 2   Cen11_NDC80_CENPA     64        32
# 3  Cen7_AuroraB_CENPA     48        24
# 4    Cen7_CENPB_CENPA     92        46
# 5   Cen7_INCENP_CENPA     46        23
# 6     Cen7_KNL1_CENPA     98        49
# 7    Cen7_NDC80_CENPA     50        25

# %%
combined_df.to_csv('combined_peak_datav2.csv')
